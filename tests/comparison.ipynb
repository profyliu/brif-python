# %%
from brif import brif
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
import time
from sklearn.metrics import accuracy_score
from sklearn import metrics
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Compare RandomForestClassifier and brif in terms of training time and test set AUC and Accuracy.
# Note: RandomForestClassifier does not take non-numeric input variables, so datasets used here all have numeric X.
# Version in comparison:
# scikit-learn 1.2.0
# brif 1.2.5

# %%
def make_X_y(df, target_var):
    X_vars = list(df.columns.values)
    X_vars.remove(target_var)
    X = df[X_vars].to_numpy()
    y = df[target_var].to_numpy()
    return X, y

# %%
# Binary classification 
csv_names = ['auto','heloc','HTRU2','magic04','optdigits','spambase','thyroid']
resp_vars = ['origin','RiskPerformance','class','class','class','spam','Class']
n_datasets = len(csv_names)

# %%
d = 2
this_csv = csv_names[d]
target_var = resp_vars[d]

# %%
# Load the data
df = pd.read_csv("data/"+this_csv+".csv")
# Split into training and test
df_train = df.sample(frac = 0.7)
df_test = df.drop(df_train.index)
all_vars = list(df.columns.values)

# %%
X_train, y_train = make_X_y(df_train, target_var)
X_test, y_test = make_X_y(df_test, target_var)

# %%
# Run randomForest
start = time.time()
clf = RandomForestClassifier(n_jobs = 4, n_estimators=200)
clf.fit(X_train, y_train)
end = time.time()
cpu_rf = end - start
pred_rf_label = clf.predict(X_test)
pred_rf_score = clf.predict_proba(X_test)
pos_label = clf.classes_[0]
score_rf = pred_rf_score[:,0]
fpr, tpr, thresholds = metrics.roc_curve(y_test, score_rf, pos_label=pos_label)
auc_rf = metrics.auc(fpr, tpr)  # Get AUC
accu_rf = accuracy_score(pred_rf_label, y_test)  # Get Accuracy

# %%
# Run brif
start = time.time()
bf = brif.brif({"nthreads":2,'ntrees':200})
bf.fit(df_train, target_var)
end = time.time()
cpu_brif = end - start
cpu_brif
# Out:
# 0.922598123550415

# %%
all_vars = list(df.columns.values)
all_vars.remove(target_var)
start = time.time()
pred_brif_label = bf.predict(df_test[all_vars], type = 'label')
end = time.time()
pred_brif_score = bf.predict(df_test[all_vars], type = 'score')
pos_label = list(pred_brif_score.columns.values)[0]
score_brif = np.array(pred_brif_score.iloc[:,0])
fpr, tpr, thresholds = metrics.roc_curve(df_test[target_var].astype(str), score_brif, pos_label=pos_label)
auc_brif = metrics.auc(fpr, tpr)  # Get AUC
accu_brif = accuracy_score(pred_brif_label, df_test[target_var].astype(str))  # Get Accuracy
print("Prediction time: {:.3f}".format(end - start))
# Out:
# Prediction time: 0.543

# %%
(auc_brif, accu_brif, cpu_brif)
# Out:
# (0.9697341663232395, 0.9759731793630099, 1.0138967037200928)

# %%
# Batch run
log_df = pd.DataFrame({"dataset":[], "n":[], "p":[], "run":[], "train_n":[], "AUC_rf":[], "AUC_brif":[], "ACCU_rf":[], "ACCU_brif":[], 
                       "CPU_rf":[], "CPU_brif":[]})
for d in range(n_datasets):
    this_csv = csv_names[d]
    target_var = resp_vars[d]
    # Load the data
    df = pd.read_csv("data/"+this_csv+".csv")
    
    for run in range(10):
        # Split into training and test
        df_train = df.sample(frac = 0.7, random_state = run*101393)
        df_test = df.drop(df_train.index)
        all_vars = list(df.columns.values)

        # Make numpy matrices for randomForest
        X_train, y_train = make_X_y(df_train, target_var)
        X_test, y_test = make_X_y(df_test, target_var)

        # Run randomForest
        start = time.time()
        clf = RandomForestClassifier(n_jobs = 4, n_estimators=200)
        clf.fit(X_train, y_train)
        end = time.time()
        cpu_rf = end - start
        pred_rf_label = clf.predict(X_test)
        pred_rf_score = clf.predict_proba(X_test)
        pos_label = clf.classes_[0]
        score_rf = pred_rf_score[:,0]
        fpr, tpr, thresholds = metrics.roc_curve(y_test, score_rf, pos_label=pos_label)
        auc_rf = metrics.auc(fpr, tpr)  # Get AUC
        accu_rf = accuracy_score(pred_rf_label, y_test)  # Get Accuracy

        # Run brif
        start = time.time()
        bf = brif.brif({"nthreads":4,'ntrees':200})
        bf.fit(df_train, target_var)
        end = time.time()
        cpu_brif = end - start

        all_vars = list(df.columns.values)
        all_vars.remove(target_var)
        #bf.nthreads = 1
        pred_brif_label = bf.predict(df_test[all_vars], type = 'label')
        pred_brif_score = bf.predict(df_test[all_vars], type = 'score')
        pos_label = list(pred_brif_score.columns.values)[0]
        score_brif = np.array(pred_brif_score.iloc[:,0])
        fpr, tpr, thresholds = metrics.roc_curve(df_test[target_var].astype(str), score_brif, pos_label=pos_label)
        auc_brif = metrics.auc(fpr, tpr)  # Get AUC
        accu_brif = accuracy_score(pred_brif_label, df_test[target_var].astype(str))  # Get Accuracy

        this_entry = pd.DataFrame({"dataset":[this_csv], "n":[df.shape[0]], "p":[df.shape[1]-1], "run":[run], "train_n":[df_train.shape[0]], 
                      "AUC_rf":[auc_rf], "AUC_brif":[auc_brif], 
                      "ACCU_rf":[accu_rf], "ACCU_brif":[accu_brif], 
                      "CPU_rf":[cpu_rf], "CPU_brif":[cpu_brif]})
        log_df = pd.concat([log_df, this_entry], ignore_index = True)
        print(this_entry)
        
display(log_df)
log_df.to_csv("results/runlog.csv")
# Out:
#   dataset    n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0    auto  392  7    0      274  0.966737  0.943962  0.932203   0.898305
#
#      CPU_rf  CPU_brif
# 0  0.175499  0.013004
#   dataset    n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0    auto  392  7    1      274  0.956522  0.951494  0.898305   0.898305
#
#      CPU_rf  CPU_brif
# 0  0.181248  0.009573
#   dataset    n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0    auto  392  7    2      274  0.964559  0.959706  0.923729    0.90678
#
#      CPU_rf  CPU_brif
# 0  0.188381  0.010006
#   dataset    n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0    auto  392  7    3      274  0.942192  0.923978  0.847458   0.838983
#
#      CPU_rf  CPU_brif
# 0  0.185259    0.0092
#   dataset    n  p  run  train_n   AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0    auto  392  7    4      274  0.95312   0.94825  0.872881   0.898305
#
#      CPU_rf  CPU_brif
# 0  0.190457  0.009163
#   dataset    n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0    auto  392  7    5      274  0.986099   0.99024  0.932203   0.957627
#
#      CPU_rf  CPU_brif
# 0  0.177305  0.013591
#   dataset    n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0    auto  392  7    6      274  0.967262  0.954132  0.881356   0.855932
#
#      CPU_rf  CPU_brif
# 0  0.201658  0.009003
#   dataset    n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0    auto  392  7    7      274  0.957968   0.95878  0.923729   0.898305
#
#      CPU_rf  CPU_brif
# 0  0.193545  0.010025
#   dataset    n  p  run  train_n    AUC_rf  AUC_brif  ACCU_rf  ACCU_brif  \
# 0    auto  392  7    8      274  0.977824   0.98142  0.90678   0.898305
#
#      CPU_rf  CPU_brif
# 0  0.202089  0.010005
#   dataset    n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0    auto  392  7    9      274  0.958295  0.949163  0.898305   0.898305
#
#      CPU_rf  CPU_brif
# 0  0.197389  0.009518
#   dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   heloc  10459  23    0     7321  0.783604  0.783804  0.719567    0.71383
#
#      CPU_rf  CPU_brif
# 0  0.757671  1.614742
#   dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   heloc  10459  23    1     7321  0.780615  0.780818  0.714786    0.72116
#
#      CPU_rf  CPU_brif
# 0  0.814149   1.69643
#   dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   heloc  10459  23    2     7321  0.790107  0.788747  0.721479     0.7116
#
#      CPU_rf  CPU_brif
# 0  0.796114  1.664027
#   dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   heloc  10459  23    3     7321  0.775966  0.779973  0.712237    0.71383
#
#      CPU_rf  CPU_brif
# 0  0.789299  1.697067
#   dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   heloc  10459  23    4     7321  0.795802  0.797809  0.728808   0.723072
#
#      CPU_rf  CPU_brif
# 0  0.791389  1.743711
#   dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   heloc  10459  23    5     7321  0.796673  0.794939  0.727852   0.720841
#
#      CPU_rf  CPU_brif
# 0  0.825424   1.77969
#   dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   heloc  10459  23    6     7321  0.784682  0.788755  0.712556   0.719567
#
#      CPU_rf  CPU_brif
# 0  0.803406  1.768936
#   dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   heloc  10459  23    7     7321  0.783883  0.782144  0.719567   0.716699
#
#      CPU_rf  CPU_brif
# 0  0.848758  1.706555
#   dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   heloc  10459  23    8     7321  0.794205  0.796124  0.726259   0.724665
#
#      CPU_rf  CPU_brif
# 0  0.841996  1.852246
#   dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   heloc  10459  23    9     7321  0.787626  0.791819  0.720841   0.718292
#
#      CPU_rf  CPU_brif
# 0  0.815849  1.829751
#   dataset      n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   HTRU2  17898  8    0    12529  0.970559  0.970652  0.977091   0.974669
#
#      CPU_rf  CPU_brif
# 0  1.758424  0.631271
#   dataset      n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   HTRU2  17898  8    1    12529  0.976001  0.976175  0.981002   0.978022
#
#      CPU_rf  CPU_brif
# 0  1.754275  0.577118
#   dataset      n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   HTRU2  17898  8    2    12529  0.966196  0.971688  0.978022   0.977649
#
#      CPU_rf  CPU_brif
# 0  1.677068  0.551019
#   dataset      n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   HTRU2  17898  8    3    12529  0.960113  0.960831  0.976904   0.972062
#
#      CPU_rf  CPU_brif
# 0  1.666893  0.573299
#   dataset      n  p  run  train_n   AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   HTRU2  17898  8    4    12529  0.96391  0.968591  0.977091   0.976532
#
#      CPU_rf  CPU_brif
# 0  1.832745  0.568188
#   dataset      n  p  run  train_n    AUC_rf  AUC_brif  ACCU_rf  ACCU_brif  \
# 0   HTRU2  17898  8    5    12529  0.974387  0.975339  0.98063   0.978767
#
#      CPU_rf  CPU_brif
# 0  1.684976   0.62309
#   dataset      n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   HTRU2  17898  8    6    12529  0.973718  0.975816  0.981375   0.981002
#
#      CPU_rf  CPU_brif
# 0  1.799425  0.628346
#   dataset      n  p  run  train_n   AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   HTRU2  17898  8    7    12529  0.97648  0.977397  0.980071   0.977463
#
#      CPU_rf  CPU_brif
# 0  1.776246  0.630821
#   dataset      n  p  run  train_n    AUC_rf  AUC_brif  ACCU_rf  ACCU_brif  \
# 0   HTRU2  17898  8    8    12529  0.976176  0.980649  0.98063   0.978208
#
#      CPU_rf  CPU_brif
# 0  1.772406  0.651465
#   dataset      n  p  run  train_n   AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   HTRU2  17898  8    9    12529  0.97443  0.978678  0.982492   0.978022
#
#      CPU_rf  CPU_brif
# 0  1.743041  0.634355
#    dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  magic04  19020  10    0    13314  0.936858  0.934243  0.881879   0.876446
#
#     CPU_rf  CPU_brif
# 0  3.84584  3.636655
#    dataset      n   p  run  train_n   AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  magic04  19020  10    1    13314  0.93255  0.929627  0.877147   0.867683
#
#      CPU_rf  CPU_brif
# 0  3.890597  3.676409
#    dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  magic04  19020  10    2    13314  0.930192  0.928545  0.876446   0.867858
#
#      CPU_rf  CPU_brif
# 0  3.880675  3.722222
#    dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  magic04  19020  10    3    13314  0.936606  0.934209  0.881528   0.877497
#
#      CPU_rf  CPU_brif
# 0  3.663304  3.623666
#    dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  magic04  19020  10    4    13314  0.937865  0.931735  0.881528   0.871013
#
#      CPU_rf  CPU_brif
# 0  3.618964  3.655157
#    dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  magic04  19020  10    5    13314  0.934689  0.931497  0.875219   0.867508
#
#      CPU_rf  CPU_brif
# 0  3.714928  3.753335
#    dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  magic04  19020  10    6    13314  0.932999  0.929596  0.873817   0.870662
#
#      CPU_rf  CPU_brif
# 0  3.697572  3.733623
#    dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  magic04  19020  10    7    13314  0.929507  0.924592  0.870662   0.861374
#
#      CPU_rf  CPU_brif
# 0  4.121705  3.876257
#    dataset      n   p  run  train_n   AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  magic04  19020  10    8    13314  0.93199  0.927361  0.876271   0.869436
#
#     CPU_rf  CPU_brif
# 0  3.90518  3.661981
#    dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  magic04  19020  10    9    13314  0.937176  0.932466  0.881353   0.865755
#
#      CPU_rf  CPU_brif
# 0  3.736946  3.640482
#      dataset     n   p  run  train_n  AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  optdigits  5620  64    0     3934     1.0       1.0  0.984579   0.985172
#
#      CPU_rf  CPU_brif
# 0  0.568133  0.652888
#      dataset     n   p  run  train_n  AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  optdigits  5620  64    1     3934     1.0       1.0  0.983393   0.985765
#
#      CPU_rf  CPU_brif
# 0  0.529152  0.550105
#      dataset     n   p  run  train_n  AUC_rf  AUC_brif  ACCU_rf  ACCU_brif  \
# 0  optdigits  5620  64    2     3934     1.0       1.0   0.9828   0.985172
#
#      CPU_rf  CPU_brif
# 0  0.517597  0.574192
#      dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  optdigits  5620  64    3     3934  0.999978   0.99998  0.983986   0.986358
#
#     CPU_rf  CPU_brif
# 0  0.49199  0.536562
#      dataset     n   p  run  train_n  AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  optdigits  5620  64    4     3934     1.0       1.0  0.987544   0.989917
#
#      CPU_rf  CPU_brif
# 0  0.575736  0.525623
#      dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  optdigits  5620  64    5     3934  0.999976  0.999996  0.978055   0.977461
#
#      CPU_rf  CPU_brif
# 0  0.553535  0.555388
#      dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  optdigits  5620  64    6     3934  0.999989  0.999989  0.980427   0.981613
#
#      CPU_rf  CPU_brif
# 0  0.507061  0.558474
#      dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  optdigits  5620  64    7     3934  0.999996       1.0  0.984579   0.986951
#
#      CPU_rf  CPU_brif
# 0  0.537936  0.575074
#      dataset     n   p  run  train_n    AUC_rf  AUC_brif  ACCU_rf  ACCU_brif  \
# 0  optdigits  5620  64    8     3934  0.999988  0.999988  0.98102   0.984579
#
#      CPU_rf  CPU_brif
# 0  0.517595  0.523368
#      dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  optdigits  5620  64    9     3934  0.999956  0.999987  0.982206   0.984579
#
#      CPU_rf  CPU_brif
# 0  0.508201  0.534081
#     dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  spambase  4601  57    0     3221  0.991286  0.991525  0.955797   0.957971
#
#     CPU_rf  CPU_brif
# 0  0.45558  0.253588
#     dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  spambase  4601  57    1     3221  0.990913  0.990228  0.955072   0.955072
#
#      CPU_rf  CPU_brif
# 0  0.431276  0.224718
#     dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  spambase  4601  57    2     3221  0.986853  0.988154  0.952174   0.957246
#
#      CPU_rf  CPU_brif
# 0  0.439001  0.211236
#     dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  spambase  4601  57    3     3221  0.985087     0.989  0.952174   0.956522
#
#      CPU_rf  CPU_brif
# 0  0.487636  0.276645
#     dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  spambase  4601  57    4     3221  0.989182  0.989477  0.953623   0.956522
#
#      CPU_rf  CPU_brif
# 0  0.507324  0.236337
#     dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  spambase  4601  57    5     3221  0.990119  0.990252  0.964493   0.958696
#
#      CPU_rf  CPU_brif
# 0  0.474319  0.231253
#     dataset     n   p  run  train_n    AUC_rf  AUC_brif  ACCU_rf  ACCU_brif  \
# 0  spambase  4601  57    6     3221  0.992258  0.991465  0.96087   0.960145
#
#      CPU_rf  CPU_brif
# 0  0.478329  0.241472
#     dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  spambase  4601  57    7     3221  0.981946  0.984665  0.944203   0.950725
#
#      CPU_rf  CPU_brif
# 0  0.461231  0.227202
#     dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  spambase  4601  57    8     3221  0.986657  0.988759  0.955797   0.960145
#
#     CPU_rf  CPU_brif
# 0  0.48684  0.226505
#     dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  spambase  4601  57    9     3221  0.985436  0.985909  0.954348    0.95942
#
#      CPU_rf  CPU_brif
# 0  0.495214  0.228192
#    dataset     n   p  run  train_n    AUC_rf  AUC_brif  ACCU_rf  ACCU_brif  \
# 0  thyroid  3772  21    0     2640  0.999579  0.999094  0.99735   0.970848
#
#      CPU_rf  CPU_brif
# 0  0.263328  0.080352
#    dataset     n   p  run  train_n    AUC_rf  AUC_brif  ACCU_rf  ACCU_brif  \
# 0  thyroid  3772  21    1     2640  0.999791  0.999444  0.99735   0.980565
#
#      CPU_rf  CPU_brif
# 0  0.289399  0.071557
#    dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  thyroid  3772  21    2     2640  0.999894  0.998681  0.995583   0.968198
#
#      CPU_rf  CPU_brif
# 0  0.292612   0.06708
#    dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  thyroid  3772  21    3     2640  0.999972  0.999972  0.998233   0.977915
#
#     CPU_rf  CPU_brif
# 0  0.29633  0.057733
#    dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  thyroid  3772  21    4     2640  0.999667  0.998471  0.995583   0.962898
#
#      CPU_rf  CPU_brif
# 0  0.297268  0.064827
#    dataset     n   p  run  train_n   AUC_rf  AUC_brif  ACCU_rf  ACCU_brif  \
# 0  thyroid  3772  21    5     2640  0.99997  0.999788   0.9947   0.979682
#
#      CPU_rf  CPU_brif
# 0  0.310594  0.058322
#    dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  thyroid  3772  21    6     2640  0.999839  0.999679  0.996466   0.966431
#
#      CPU_rf  CPU_brif
# 0  0.320984  0.067774
#    dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  thyroid  3772  21    7     2640  0.998463  0.998512  0.992933   0.968198
#
#      CPU_rf  CPU_brif
# 0  0.299121  0.059255
#    dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  thyroid  3772  21    8     2640  0.999826  0.999478  0.992933   0.970848
#
#     CPU_rf  CPU_brif
# 0  0.30505  0.064799
#    dataset     n   p  run  train_n    AUC_rf  AUC_brif  ACCU_rf  ACCU_brif  \
# 0  thyroid  3772  21    9     2640  0.999894  0.999788  0.99735   0.969965
#
#      CPU_rf  CPU_brif
# 0  0.324598  0.057933
#     dataset       n     p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  \
# 0      auto   392.0   7.0  0.0    274.0  0.966737  0.943962  0.932203
# 1      auto   392.0   7.0  1.0    274.0  0.956522  0.951494  0.898305
# 2      auto   392.0   7.0  2.0    274.0  0.964559  0.959706  0.923729
# 3      auto   392.0   7.0  3.0    274.0  0.942192  0.923978  0.847458
# 4      auto   392.0   7.0  4.0    274.0  0.953120  0.948250  0.872881
# ..      ...     ...   ...  ...      ...       ...       ...       ...
# 65  thyroid  3772.0  21.0  5.0   2640.0  0.999970  0.999788  0.994700
# 66  thyroid  3772.0  21.0  6.0   2640.0  0.999839  0.999679  0.996466
# 67  thyroid  3772.0  21.0  7.0   2640.0  0.998463  0.998512  0.992933
# 68  thyroid  3772.0  21.0  8.0   2640.0  0.999826  0.999478  0.992933
# 69  thyroid  3772.0  21.0  9.0   2640.0  0.999894  0.999788  0.997350
#
#     ACCU_brif    CPU_rf  CPU_brif
# 0    0.898305  0.175499  0.013004
# 1    0.898305  0.181248  0.009573
# 2    0.906780  0.188381  0.010006
# 3    0.838983  0.185259  0.009200
# 4    0.898305  0.190457  0.009163
# ..        ...       ...       ...
# 65   0.979682  0.310594  0.058322
# 66   0.966431  0.320984  0.067774
# 67   0.968198  0.299121  0.059255
# 68   0.970848  0.305050  0.064799
# 69   0.969965  0.324598  0.057933
#
# [70 rows x 11 columns]

# %%
log_df.groupby('dataset').mean()
# Out:
#                  n     p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  \
# dataset
# HTRU2      17898.0   8.0  4.5  12529.0  0.971197  0.973582  0.979531
# auto         392.0   7.0  4.5    274.0  0.963058  0.956112  0.901695
# heloc      10459.0  23.0  4.5   7321.0  0.787316  0.788493  0.720395
# magic04    19020.0  10.0  4.5  13314.0  0.934043  0.930387  0.877585
# optdigits   5620.0  64.0  4.5   3934.0  0.999988  0.999994  0.982859
# spambase    4601.0  57.0  4.5   3221.0  0.987974  0.988943  0.954855
# thyroid     3772.0  21.0  4.5   2640.0  0.999690  0.999291  0.995848
#
#            ACCU_brif    CPU_rf  CPU_brif
# dataset
# HTRU2       0.977240  1.746550  0.606897
# auto        0.894915  0.189283  0.010309
# heloc       0.718356  0.808405  1.735315
# magic04     0.869523  3.807571  3.697979
# optdigits   0.984757  0.530694  0.558575
# spambase    0.957246  0.471675  0.235715
# thyroid     0.971555  0.299928  0.064963

# %% [markdown]
# Observation: brif and RandomForestClassifier performed neck and neck in all aspects.
