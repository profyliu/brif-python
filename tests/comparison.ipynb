# %%
import brif
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
import time
from sklearn.metrics import accuracy_score
from sklearn import metrics
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Compare RandomForestClassifier and brif in terms of training time and test set AUC and Accuracy.
# Note: RandomForestClassifier does not take non-numeric input variables, so datasets used here all have numeric X.

# %%
def make_X_y(df, target_var):
    X_vars = list(df.columns.values)
    X_vars.remove(target_var)
    X = df[X_vars].to_numpy()
    y = df[target_var].to_numpy()
    return X, y

# %%
# Binary classification 
csv_names = ['auto','heloc','HTRU2','magic04','optdigits','spambase','thyroid']
resp_vars = ['origin','RiskPerformance','class','class','class','spam','Class']
n_datasets = len(csv_names)

# %%
d = 2
this_csv = csv_names[d]
target_var = resp_vars[d]

# %%
# Load the data
df = pd.read_csv("data/"+this_csv+".csv")
# Split into training and test
df_train = df.sample(frac = 0.7)
df_test = df.drop(df_train.index)
all_vars = list(df.columns.values)

# %%
X_train, y_train = make_X_y(df_train, target_var)
X_test, y_test = make_X_y(df_test, target_var)

# %%
# Run randomForest
start = time.time()
clf = RandomForestClassifier(n_jobs = 4, n_estimators=200)
clf.fit(X_train, y_train)
end = time.time()
cpu_rf = end - start
pred_rf_label = clf.predict(X_test)
pred_rf_score = clf.predict_proba(X_test)
pos_label = clf.classes_[0]
score_rf = pred_rf_score[:,0]
fpr, tpr, thresholds = metrics.roc_curve(y_test, score_rf, pos_label=pos_label)
auc_rf = metrics.auc(fpr, tpr)  # Get AUC
accu_rf = accuracy_score(pred_rf_label, y_test)  # Get Accuracy

# %%
# Run brif
start = time.time()
bf = brif.brif({"nthreads":4,'ntrees':200})
bf.fit(df_train, target_var)
end = time.time()
cpu_brif = end - start

# %%
all_vars = list(df.columns.values)
all_vars.remove(target_var)
start = time.time()
pred_brif_label = bf.predict(df_test[all_vars], type = 'label')
end = time.time()
pred_brif_score = bf.predict(df_test[all_vars], type = 'score')
pos_label = list(pred_brif_score.columns.values)[0]
score_brif = np.array(pred_brif_score.iloc[:,0])
fpr, tpr, thresholds = metrics.roc_curve(df_test[target_var].astype(str), score_brif, pos_label=pos_label)
auc_brif = metrics.auc(fpr, tpr)  # Get AUC
accu_brif = accuracy_score(pred_brif_label, df_test[target_var].astype(str))  # Get Accuracy
print("Prediction time: {:.3f}".format(end - start))
# Out:
# Prediction time: 0.265

# %%
# Batch run
log_df = pd.DataFrame({"dataset":[], "n":[], "p":[], "run":[], "train_n":[], "AUC_rf":[], "AUC_brif":[], "ACCU_rf":[], "ACCU_brif":[], 
                       "CPU_rf":[], "CPU_brif":[]})
for d in range(n_datasets):
    this_csv = csv_names[d]
    target_var = resp_vars[d]
    # Load the data
    df = pd.read_csv("data/"+this_csv+".csv")
    
    for run in range(10):
        # Split into training and test
        df_train = df.sample(frac = 0.7, random_state = run*101393)
        df_test = df.drop(df_train.index)
        all_vars = list(df.columns.values)

        # Make numpy matrices for randomForest
        X_train, y_train = make_X_y(df_train, target_var)
        X_test, y_test = make_X_y(df_test, target_var)

        # Run randomForest
        start = time.time()
        clf = RandomForestClassifier(n_jobs = 4, n_estimators=200)
        clf.fit(X_train, y_train)
        end = time.time()
        cpu_rf = end - start
        pred_rf_label = clf.predict(X_test)
        pred_rf_score = clf.predict_proba(X_test)
        pos_label = clf.classes_[0]
        score_rf = pred_rf_score[:,0]
        fpr, tpr, thresholds = metrics.roc_curve(y_test, score_rf, pos_label=pos_label)
        auc_rf = metrics.auc(fpr, tpr)  # Get AUC
        accu_rf = accuracy_score(pred_rf_label, y_test)  # Get Accuracy

        # Run brif
        start = time.time()
        bf = brif.brif({"nthreads":4,'ntrees':200})
        bf.fit(df_train, target_var)
        end = time.time()
        cpu_brif = end - start

        all_vars = list(df.columns.values)
        all_vars.remove(target_var)
        pred_brif_label = bf.predict(df_test[all_vars], type = 'label')
        pred_brif_score = bf.predict(df_test[all_vars], type = 'score')
        pos_label = list(pred_brif_score.columns.values)[0]
        score_brif = np.array(pred_brif_score.iloc[:,0])
        fpr, tpr, thresholds = metrics.roc_curve(df_test[target_var].astype(str), score_brif, pos_label=pos_label)
        auc_brif = metrics.auc(fpr, tpr)  # Get AUC
        accu_brif = accuracy_score(pred_brif_label, df_test[target_var].astype(str))  # Get Accuracy

        this_entry = pd.DataFrame({"dataset":[this_csv], "n":[df.shape[0]], "p":[df.shape[1]-1], "run":[run], "train_n":[df_train.shape[0]], 
                      "AUC_rf":[auc_rf], "AUC_brif":[auc_brif], 
                      "ACCU_rf":[accu_rf], "ACCU_brif":[accu_brif], 
                      "CPU_rf":[cpu_rf], "CPU_brif":[cpu_brif]})
        log_df = pd.concat([log_df, this_entry], ignore_index = True)
        print(this_entry)
        
display(log_df)
log_df.to_csv("results/runlog.csv")
# Out:
#   dataset    n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0    auto  392  7    0      274  0.967486  0.959245  0.923729    0.90678
#
#      CPU_rf  CPU_brif
# 0  0.220073     0.015
#   dataset    n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0    auto  392  7    1      274  0.954008  0.947944  0.889831    0.90678
#
#      CPU_rf  CPU_brif
# 0  0.239875     0.011
#   dataset    n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0    auto  392  7    2      274  0.963824  0.962647  0.923729   0.923729
#
#      CPU_rf  CPU_brif
# 0  0.225131  0.013653
#   dataset    n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0    auto  392  7    3      274  0.933481  0.933164  0.847458   0.830508
#
#      CPU_rf  CPU_brif
# 0  0.219997     0.011
#   dataset    n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0    auto  392  7    4      274  0.954186  0.943379  0.881356   0.872881
#
#    CPU_rf  CPU_brif
# 0  0.2182  0.011004
#   dataset    n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0    auto  392  7    5      274  0.983881  0.980183  0.932203   0.923729
#
#      CPU_rf  CPU_brif
# 0  0.226044  0.013004
#   dataset    n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0    auto  392  7    6      274  0.970588  0.957633  0.872881   0.864407
#
#      CPU_rf  CPU_brif
# 0  0.216091     0.012
#   dataset    n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0    auto  392  7    7      274  0.956508  0.939305  0.923729   0.898305
#
#      CPU_rf  CPU_brif
# 0  0.219095  0.010001
#   dataset    n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0    auto  392  7    8      274  0.980821  0.978424  0.915254   0.915254
#
#     CPU_rf  CPU_brif
# 0  0.21657  0.012066
#   dataset    n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0    auto  392  7    9      274  0.959361  0.950989  0.898305    0.90678
#
#      CPU_rf  CPU_brif
# 0  0.217161  0.009999
#   dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   heloc  10459  23    0     7321  0.783693  0.784314  0.720841   0.715743
#
#      CPU_rf  CPU_brif
# 0  0.839097  2.004071
#   dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   heloc  10459  23    1     7321  0.779285  0.781283  0.713193   0.716699
#
#     CPU_rf  CPU_brif
# 0  0.86595  2.123059
#   dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   heloc  10459  23    2     7321  0.787289  0.787371  0.722116    0.71638
#
#      CPU_rf  CPU_brif
# 0  0.866772  2.270657
#   dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   heloc  10459  23    3     7321  0.779494  0.779276  0.715105   0.710644
#
#      CPU_rf  CPU_brif
# 0  0.854903   2.39821
#   dataset      n   p  run  train_n   AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   heloc  10459  23    4     7321  0.79357  0.798458  0.725621   0.721797
#
#      CPU_rf  CPU_brif
# 0  0.840223  2.180166
#   dataset      n   p  run  train_n   AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   heloc  10459  23    5     7321  0.79499  0.795766  0.722753   0.723072
#
#      CPU_rf  CPU_brif
# 0  0.874827  2.261623
#   dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   heloc  10459  23    6     7321  0.783279  0.785045  0.711918    0.71383
#
#      CPU_rf  CPU_brif
# 0  0.916167  2.180997
#   dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   heloc  10459  23    7     7321  0.783734  0.781922  0.718292   0.718611
#
#     CPU_rf  CPU_brif
# 0  0.91016  2.249078
#   dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   heloc  10459  23    8     7321  0.793714  0.795853  0.725621   0.723391
#
#      CPU_rf  CPU_brif
# 0  0.901375  2.312648
#   dataset      n   p  run  train_n   AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   heloc  10459  23    9     7321  0.79158  0.787833  0.721797   0.717973
#
#     CPU_rf  CPU_brif
# 0  0.95455  2.318274
#   dataset      n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   HTRU2  17898  8    0    12529  0.969437   0.96865  0.977649   0.973179
#
#      CPU_rf  CPU_brif
# 0  1.948836  0.839509
#   dataset      n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   HTRU2  17898  8    1    12529  0.973565  0.976835  0.981188   0.977091
#
#      CPU_rf  CPU_brif
# 0  2.033921  0.852985
#   dataset      n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   HTRU2  17898  8    2    12529  0.964905  0.970995  0.977463   0.977277
#
#      CPU_rf  CPU_brif
# 0  2.015502   0.76413
#   dataset      n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   HTRU2  17898  8    3    12529  0.956495  0.960545  0.977091   0.972248
#
#      CPU_rf  CPU_brif
# 0  1.930924  0.707044
#   dataset      n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   HTRU2  17898  8    4    12529  0.962564  0.973116  0.976718   0.976532
#
#      CPU_rf  CPU_brif
# 0  2.008719  0.770249
#   dataset      n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   HTRU2  17898  8    5    12529  0.975101  0.975236  0.980443   0.978394
#
#      CPU_rf  CPU_brif
# 0  1.927431  0.819978
#   dataset      n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   HTRU2  17898  8    6    12529  0.972676  0.975696  0.981747   0.979885
#
#      CPU_rf  CPU_brif
# 0  1.917263  0.727549
#   dataset      n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   HTRU2  17898  8    7    12529  0.975353  0.976587  0.979512   0.977277
#
#      CPU_rf  CPU_brif
# 0  1.946187  0.796071
#   dataset      n  p  run  train_n    AUC_rf  AUC_brif  ACCU_rf  ACCU_brif  \
# 0   HTRU2  17898  8    8    12529  0.974878  0.979689  0.98063   0.978022
#
#      CPU_rf  CPU_brif
# 0  1.842893  0.699882
#   dataset      n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   HTRU2  17898  8    9    12529  0.973097  0.978082  0.981561   0.978581
#
#      CPU_rf  CPU_brif
# 0  1.829334  0.759988
#    dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  magic04  19020  10    0    13314  0.936947    0.9337  0.882054   0.876972
#
#      CPU_rf  CPU_brif
# 0  3.979398  4.391531
#    dataset      n   p  run  train_n   AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  magic04  19020  10    1    13314  0.93212   0.92949  0.877322   0.863477
#
#      CPU_rf  CPU_brif
# 0  3.726667  4.612577
#    dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  magic04  19020  10    2    13314  0.930296  0.927448  0.876796   0.867858
#
#    CPU_rf  CPU_brif
# 0  3.6341  4.368836
#    dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  magic04  19020  10    3    13314  0.936941  0.934085  0.881353   0.874343
#
#      CPU_rf  CPU_brif
# 0  4.012553  4.464588
#    dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  magic04  19020  10    4    13314  0.938037  0.931794  0.880126   0.869611
#
#      CPU_rf  CPU_brif
# 0  3.911069  4.500569
#    dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  magic04  19020  10    5    13314  0.934654  0.931623  0.877497   0.868384
#
#      CPU_rf  CPU_brif
# 0  3.933884  4.555346
#    dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  magic04  19020  10    6    13314  0.931737  0.929715  0.873467   0.870137
#
#      CPU_rf  CPU_brif
# 0  3.859896  4.434311
#    dataset      n   p  run  train_n    AUC_rf  AUC_brif  ACCU_rf  ACCU_brif  \
# 0  magic04  19020  10    7    13314  0.929791  0.924895  0.87259   0.858395
#
#      CPU_rf  CPU_brif
# 0  4.136166  4.809839
#    dataset      n   p  run  train_n    AUC_rf  AUC_brif  ACCU_rf  ACCU_brif  \
# 0  magic04  19020  10    8    13314  0.931581  0.928398  0.87557   0.868209
#
#    CPU_rf  CPU_brif
# 0  5.3716  5.231094
#    dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  magic04  19020  10    9    13314  0.937237  0.932355  0.879776   0.867858
#
#      CPU_rf  CPU_brif
# 0  4.429917    4.6624
#      dataset     n   p  run  train_n  AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  optdigits  5620  64    0     3934     1.0       1.0  0.983986   0.986951
#
#      CPU_rf  CPU_brif
# 0  0.604385  1.138982
#      dataset     n   p  run  train_n  AUC_rf  AUC_brif  ACCU_rf  ACCU_brif  \
# 0  optdigits  5620  64    1     3934     1.0       1.0   0.9828   0.985765
#
#      CPU_rf  CPU_brif
# 0  0.599486  1.061721
#      dataset     n   p  run  train_n  AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  optdigits  5620  64    2     3934     1.0       1.0  0.982206   0.983393
#
#      CPU_rf  CPU_brif
# 0  0.630608  1.059459
#      dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  optdigits  5620  64    3     3934  0.999968  0.999984  0.984579   0.986951
#
#      CPU_rf  CPU_brif
# 0  0.583429  1.006139
#      dataset     n   p  run  train_n  AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  optdigits  5620  64    4     3934     1.0       1.0  0.985765   0.986951
#
#      CPU_rf  CPU_brif
# 0  0.641191  1.031105
#      dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  optdigits  5620  64    5     3934  0.999974       1.0  0.978055   0.980427
#
#      CPU_rf  CPU_brif
# 0  0.641916  0.984956
#      dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  optdigits  5620  64    6     3934  0.999996       1.0  0.979241     0.9828
#
#      CPU_rf  CPU_brif
# 0  0.570958  0.906555
#      dataset     n   p  run  train_n  AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  optdigits  5620  64    7     3934     1.0       1.0  0.984579   0.985172
#
#      CPU_rf  CPU_brif
# 0  0.725389  1.436655
#      dataset     n   p  run  train_n    AUC_rf  AUC_brif  ACCU_rf  ACCU_brif  \
# 0  optdigits  5620  64    8     3934  0.999983  0.999996   0.9828     0.9828
#
#      CPU_rf  CPU_brif
# 0  0.904893   1.49174
#      dataset     n   p  run  train_n    AUC_rf  AUC_brif  ACCU_rf  ACCU_brif  \
# 0  optdigits  5620  64    9     3934  0.999912  0.999979  0.98102   0.986951
#
#      CPU_rf  CPU_brif
# 0  0.785368  1.081007
#     dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  spambase  4601  57    0     3221  0.991457  0.991758  0.957246   0.963043
#
#      CPU_rf  CPU_brif
# 0  0.503871  0.345352
#     dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  spambase  4601  57    1     3221  0.991095  0.990192  0.954348   0.951449
#
#     CPU_rf  CPU_brif
# 0  0.65452  0.311325
#     dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  spambase  4601  57    2     3221  0.987253  0.988222  0.956522   0.953623
#
#      CPU_rf  CPU_brif
# 0  0.519272  0.356151
#     dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  spambase  4601  57    3     3221  0.986714  0.989137  0.955072   0.958696
#
#      CPU_rf  CPU_brif
# 0  0.564931  0.296113
#     dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  spambase  4601  57    4     3221  0.989887  0.989891  0.953623   0.957246
#
#      CPU_rf  CPU_brif
# 0  0.523525  0.344949
#     dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  spambase  4601  57    5     3221  0.990986  0.989997  0.964493    0.95942
#
#      CPU_rf  CPU_brif
# 0  0.511582  0.415224
#     dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  spambase  4601  57    6     3221  0.992179  0.991473  0.957971    0.96087
#
#      CPU_rf  CPU_brif
# 0  0.511856  0.298825
#     dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  spambase  4601  57    7     3221  0.982944  0.984261  0.944928   0.948551
#
#      CPU_rf  CPU_brif
# 0  0.550833  0.258499
#     dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  spambase  4601  57    8     3221  0.988021  0.988955  0.957246   0.962319
#
#     CPU_rf  CPU_brif
# 0  0.50082    0.3491
#     dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  spambase  4601  57    9     3221  0.985232  0.986729  0.957971   0.957971
#
#      CPU_rf  CPU_brif
# 0  0.487803   0.28504
#    dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  thyroid  3772  21    0     2640  0.999579  0.999159  0.998233   0.972615
#
#      CPU_rf  CPU_brif
# 0  0.290354  0.094057
#    dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  thyroid  3772  21    1     2640  0.999861   0.99927  0.996466   0.980565
#
#      CPU_rf  CPU_brif
# 0  0.317999  0.072999
#    dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  thyroid  3772  21    2     2640  0.999894   0.99847  0.995583   0.970848
#
#     CPU_rf  CPU_brif
# 0  0.32179  0.088341
#    dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  thyroid  3772  21    3     2640  0.999972  0.999886  0.998233   0.971731
#
#      CPU_rf  CPU_brif
# 0  0.365974  0.080999
#    dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  thyroid  3772  21    4     2640  0.999647  0.998941  0.995583   0.961131
#
#      CPU_rf  CPU_brif
# 0  0.315101  0.072046
#    dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  thyroid  3772  21    5     2640  0.999955  0.999667  0.993816   0.972615
#
#      CPU_rf  CPU_brif
# 0  0.292132  0.076047
#    dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  thyroid  3772  21    6     2640  0.999839  0.999679  0.996466   0.965548
#
#      CPU_rf  CPU_brif
# 0  0.269531   0.06905
#    dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  thyroid  3772  21    7     2640  0.998334   0.99835  0.991166   0.967314
#
#      CPU_rf  CPU_brif
# 0  0.283914     0.072
#    dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  thyroid  3772  21    8     2640  0.999878  0.999687  0.995583   0.969965
#
#      CPU_rf  CPU_brif
# 0  0.275993  0.075999
#    dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  thyroid  3772  21    9     2640  0.999879  0.999637  0.998233   0.970848
#
#      CPU_rf  CPU_brif
# 0  0.293996  0.066999
#     dataset       n     p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  \
# 0      auto   392.0   7.0  0.0    274.0  0.967486  0.959245  0.923729
# 1      auto   392.0   7.0  1.0    274.0  0.954008  0.947944  0.889831
# 2      auto   392.0   7.0  2.0    274.0  0.963824  0.962647  0.923729
# 3      auto   392.0   7.0  3.0    274.0  0.933481  0.933164  0.847458
# 4      auto   392.0   7.0  4.0    274.0  0.954186  0.943379  0.881356
# ..      ...     ...   ...  ...      ...       ...       ...       ...
# 65  thyroid  3772.0  21.0  5.0   2640.0  0.999955  0.999667  0.993816
# 66  thyroid  3772.0  21.0  6.0   2640.0  0.999839  0.999679  0.996466
# 67  thyroid  3772.0  21.0  7.0   2640.0  0.998334  0.998350  0.991166
# 68  thyroid  3772.0  21.0  8.0   2640.0  0.999878  0.999687  0.995583
# 69  thyroid  3772.0  21.0  9.0   2640.0  0.999879  0.999637  0.998233
#
#     ACCU_brif    CPU_rf  CPU_brif
# 0    0.906780  0.220073  0.015000
# 1    0.906780  0.239875  0.011000
# 2    0.923729  0.225131  0.013653
# 3    0.830508  0.219997  0.011000
# 4    0.872881  0.218200  0.011004
# ..        ...       ...       ...
# 65   0.972615  0.292132  0.076047
# 66   0.965548  0.269531  0.069050
# 67   0.967314  0.283914  0.072000
# 68   0.969965  0.275993  0.075999
# 69   0.970848  0.293996  0.066999
#
# [70 rows x 11 columns]

# %%
log_df.groupby('dataset').mean()
# Out:
#                  n     p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  \
# dataset
# HTRU2      17898.0   8.0  4.5  12529.0  0.969807  0.973543  0.979400
# auto         392.0   7.0  4.5    274.0  0.962414  0.955291  0.900847
# heloc      10459.0  23.0  4.5   7321.0  0.787063  0.787712  0.719726
# magic04    19020.0  10.0  4.5  13314.0  0.933934  0.930350  0.877655
# optdigits   5620.0  64.0  4.5   3934.0  0.999983  0.999996  0.982503
# spambase    4601.0  57.0  4.5   3221.0  0.988577  0.989062  0.955942
# thyroid     3772.0  21.0  4.5   2640.0  0.999684  0.999275  0.995936
#
#            ACCU_brif    CPU_rf  CPU_brif
# dataset
# HTRU2       0.976849  1.940101  0.773739
# auto        0.894915  0.221824  0.011873
# heloc       0.717814  0.882402  2.229878
# magic04     0.868524  4.099525  4.603109
# optdigits   0.984816  0.668762  1.119832
# spambase    0.957319  0.532901  0.326058
# thyroid     0.970318  0.302679  0.076854

# %% [markdown]
# Observation: brif and RandomForestClassifier performed neck and neck in all aspects.
