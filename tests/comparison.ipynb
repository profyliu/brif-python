# %%
import brif
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
import time
from sklearn.metrics import accuracy_score
from sklearn import metrics
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Compare RandomForestClassifier and brif in terms of training time and test set AUC and Accuracy.
# Note: RandomForestClassifier does not take non-numeric input variables, so datasets used here all have numeric X.
# Version in comparison:
# scikit-learn 1.2.0
# brif 1.2.5

# %%
def make_X_y(df, target_var):
    X_vars = list(df.columns.values)
    X_vars.remove(target_var)
    X = df[X_vars].to_numpy()
    y = df[target_var].to_numpy()
    return X, y

# %%
# Binary classification 
csv_names = ['auto','heloc','HTRU2','magic04','optdigits','spambase','thyroid']
resp_vars = ['origin','RiskPerformance','class','class','class','spam','Class']
n_datasets = len(csv_names)

# %%
d = 2
this_csv = csv_names[d]
target_var = resp_vars[d]

# %%
# Load the data
df = pd.read_csv("data/"+this_csv+".csv")
# Split into training and test
df_train = df.sample(frac = 0.7)
df_test = df.drop(df_train.index)
all_vars = list(df.columns.values)

# %%
X_train, y_train = make_X_y(df_train, target_var)
X_test, y_test = make_X_y(df_test, target_var)

# %%
# Run randomForest
start = time.time()
clf = RandomForestClassifier(n_jobs = 4, n_estimators=200)
clf.fit(X_train, y_train)
end = time.time()
cpu_rf = end - start
pred_rf_label = clf.predict(X_test)
pred_rf_score = clf.predict_proba(X_test)
pos_label = clf.classes_[0]
score_rf = pred_rf_score[:,0]
fpr, tpr, thresholds = metrics.roc_curve(y_test, score_rf, pos_label=pos_label)
auc_rf = metrics.auc(fpr, tpr)  # Get AUC
accu_rf = accuracy_score(pred_rf_label, y_test)  # Get Accuracy

# %%
# Run brif
start = time.time()
bf = brif.brif({"nthreads":8,'ntrees':200})
bf.fit(df_train, target_var)
end = time.time()
cpu_brif = end - start
cpu_brif
# Out:
# 0.2950122356414795

# %%
all_vars = list(df.columns.values)
all_vars.remove(target_var)
start = time.time()
pred_brif_label = bf.predict(df_test[all_vars], type = 'label')
end = time.time()
pred_brif_score = bf.predict(df_test[all_vars], type = 'score')
pos_label = list(pred_brif_score.columns.values)[0]
score_brif = np.array(pred_brif_score.iloc[:,0])
fpr, tpr, thresholds = metrics.roc_curve(df_test[target_var].astype(str), score_brif, pos_label=pos_label)
auc_brif = metrics.auc(fpr, tpr)  # Get AUC
accu_brif = accuracy_score(pred_brif_label, df_test[target_var].astype(str))  # Get Accuracy
print("Prediction time: {:.3f}".format(end - start))
# Out:
# Prediction time: 0.188

# %%
(auc_brif, accu_brif, cpu_brif)
# Out:
# (0.9746562749603505, 0.9769044514807227, 0.2950122356414795)

# %%
# Batch run
log_df = pd.DataFrame({"dataset":[], "n":[], "p":[], "run":[], "train_n":[], "AUC_rf":[], "AUC_brif":[], "ACCU_rf":[], "ACCU_brif":[], 
                       "CPU_rf":[], "CPU_brif":[]})
for d in range(n_datasets):
    this_csv = csv_names[d]
    target_var = resp_vars[d]
    # Load the data
    df = pd.read_csv("data/"+this_csv+".csv")
    
    for run in range(10):
        # Split into training and test
        df_train = df.sample(frac = 0.7, random_state = run*101393)
        df_test = df.drop(df_train.index)
        all_vars = list(df.columns.values)

        # Make numpy matrices for randomForest
        X_train, y_train = make_X_y(df_train, target_var)
        X_test, y_test = make_X_y(df_test, target_var)

        # Run randomForest
        start = time.time()
        clf = RandomForestClassifier(n_jobs = 4, n_estimators=200)
        clf.fit(X_train, y_train)
        end = time.time()
        cpu_rf = end - start
        pred_rf_label = clf.predict(X_test)
        pred_rf_score = clf.predict_proba(X_test)
        pos_label = clf.classes_[0]
        score_rf = pred_rf_score[:,0]
        fpr, tpr, thresholds = metrics.roc_curve(y_test, score_rf, pos_label=pos_label)
        auc_rf = metrics.auc(fpr, tpr)  # Get AUC
        accu_rf = accuracy_score(pred_rf_label, y_test)  # Get Accuracy

        # Run brif
        start = time.time()
        bf = brif.brif({"nthreads":4,'ntrees':200})
        bf.fit(df_train, target_var)
        end = time.time()
        cpu_brif = end - start

        all_vars = list(df.columns.values)
        all_vars.remove(target_var)
        pred_brif_label = bf.predict(df_test[all_vars], type = 'label')
        pred_brif_score = bf.predict(df_test[all_vars], type = 'score')
        pos_label = list(pred_brif_score.columns.values)[0]
        score_brif = np.array(pred_brif_score.iloc[:,0])
        fpr, tpr, thresholds = metrics.roc_curve(df_test[target_var].astype(str), score_brif, pos_label=pos_label)
        auc_brif = metrics.auc(fpr, tpr)  # Get AUC
        accu_brif = accuracy_score(pred_brif_label, df_test[target_var].astype(str))  # Get Accuracy

        this_entry = pd.DataFrame({"dataset":[this_csv], "n":[df.shape[0]], "p":[df.shape[1]-1], "run":[run], "train_n":[df_train.shape[0]], 
                      "AUC_rf":[auc_rf], "AUC_brif":[auc_brif], 
                      "ACCU_rf":[accu_rf], "ACCU_brif":[accu_brif], 
                      "CPU_rf":[cpu_rf], "CPU_brif":[cpu_brif]})
        log_df = pd.concat([log_df, this_entry], ignore_index = True)
        print(this_entry)
        
display(log_df)
log_df.to_csv("results/runlog.csv")
# Out:
#   dataset    n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0    auto  392  7    0      274  0.970333  0.943962  0.923729   0.864407
#
#      CPU_rf  CPU_brif
# 0  0.169966     0.007
#   dataset    n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0    auto  392  7    1      274  0.957557  0.918367  0.881356   0.855932
#
#      CPU_rf  CPU_brif
# 0  0.176373     0.008
#   dataset    n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0    auto  392  7    2      274  0.966471  0.947059  0.915254   0.889831
#
#    CPU_rf  CPU_brif
# 0  0.1745  0.007996
#   dataset    n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0    auto  392  7    3      274  0.932373  0.912258  0.855932   0.855932
#
#      CPU_rf  CPU_brif
# 0  0.171213  0.007999
#   dataset    n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0    auto  392  7    4      274  0.953425  0.925723  0.872881   0.830508
#
#      CPU_rf  CPU_brif
# 0  0.166947  0.007999
#   dataset    n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0    auto  392  7    5      274  0.986838  0.965986  0.957627   0.889831
#
#      CPU_rf  CPU_brif
# 0  0.170196     0.009
#   dataset    n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0    auto  392  7    6      274  0.966912  0.943627  0.872881   0.872881
#
#      CPU_rf  CPU_brif
# 0  0.172043  0.008999
#   dataset    n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0    auto  392  7    7      274  0.956832  0.939955  0.915254   0.881356
#
#      CPU_rf  CPU_brif
# 0  0.167753     0.008
#   dataset    n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0    auto  392  7    8      274  0.977675  0.968834  0.915254   0.889831
#
#      CPU_rf  CPU_brif
# 0  0.172547  0.007999
#   dataset    n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0    auto  392  7    9      274  0.954338  0.930289  0.889831   0.855932
#
#      CPU_rf  CPU_brif
# 0  0.176083     0.008
#   dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   heloc  10459  23    0     7321  0.783395  0.783897  0.718611   0.717336
#
#      CPU_rf  CPU_brif
# 0  0.745062  1.495981
#   dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   heloc  10459  23    1     7321  0.779219  0.780213  0.717655   0.717973
#
#      CPU_rf  CPU_brif
# 0  0.727429  1.479375
#   dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   heloc  10459  23    2     7321  0.788223  0.789616  0.724028   0.715424
#
#      CPU_rf  CPU_brif
# 0  0.742619  1.523142
#   dataset      n   p  run  train_n   AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   heloc  10459  23    3     7321  0.77645  0.777396  0.715424   0.716061
#
#     CPU_rf  CPU_brif
# 0  0.72819  1.560071
#   dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   heloc  10459  23    4     7321  0.795429  0.797656  0.728171   0.720841
#
#      CPU_rf  CPU_brif
# 0  0.762195  1.525598
#   dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   heloc  10459  23    5     7321  0.794267  0.794113  0.727533   0.724984
#
#      CPU_rf  CPU_brif
# 0  0.778376  1.443646
#   dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   heloc  10459  23    6     7321  0.785902  0.787039  0.711281   0.716699
#
#      CPU_rf  CPU_brif
# 0  0.652239  1.619876
#   dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   heloc  10459  23    7     7321  0.783225  0.782202  0.720523   0.713512
#
#      CPU_rf  CPU_brif
# 0  0.717019  1.567431
#   dataset      n   p  run  train_n   AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   heloc  10459  23    8     7321  0.79387  0.796292  0.730083   0.724984
#
#      CPU_rf  CPU_brif
# 0  0.733667  1.628473
#   dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   heloc  10459  23    9     7321  0.793083  0.791916  0.724347   0.715743
#
#     CPU_rf  CPU_brif
# 0  0.77862  1.576813
#   dataset      n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   HTRU2  17898  8    0    12529  0.967734  0.968894  0.977463   0.974111
#
#      CPU_rf  CPU_brif
# 0  1.842925  0.584225
#   dataset      n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   HTRU2  17898  8    1    12529  0.974241  0.977308  0.980443   0.977463
#
#      CPU_rf  CPU_brif
# 0  1.681985  0.525139
#   dataset      n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   HTRU2  17898  8    2    12529  0.966149   0.97085  0.977836   0.976718
#
#      CPU_rf  CPU_brif
# 0  1.472595  0.478129
#   dataset      n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   HTRU2  17898  8    3    12529  0.960239  0.960592  0.977091   0.971503
#
#      CPU_rf  CPU_brif
# 0  1.918957  0.461734
#   dataset      n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   HTRU2  17898  8    4    12529  0.959874  0.970675  0.976346   0.976532
#
#      CPU_rf  CPU_brif
# 0  1.923135  0.512265
#   dataset      n  p  run  train_n    AUC_rf  AUC_brif  ACCU_rf  ACCU_brif  \
# 0   HTRU2  17898  8    5    12529  0.974408   0.97636  0.98063   0.978581
#
#      CPU_rf  CPU_brif
# 0  1.894603   0.56462
#   dataset      n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   HTRU2  17898  8    6    12529  0.974011  0.975172  0.981933   0.980443
#
#      CPU_rf  CPU_brif
# 0  1.710374  0.541203
#   dataset      n  p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   HTRU2  17898  8    7    12529  0.976162  0.976974  0.979885   0.978394
#
#      CPU_rf  CPU_brif
# 0  1.650629  0.525228
#   dataset      n  p  run  train_n    AUC_rf  AUC_brif  ACCU_rf  ACCU_brif  \
# 0   HTRU2  17898  8    8    12529  0.972211  0.980421  0.98063   0.977836
#
#      CPU_rf  CPU_brif
# 0  1.711357  0.544418
#   dataset      n  p  run  train_n   AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0   HTRU2  17898  8    9    12529  0.97493   0.98003  0.982306   0.978394
#
#      CPU_rf  CPU_brif
# 0  1.926135  0.554502
#    dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  magic04  19020  10    0    13314  0.937006  0.932825  0.881528   0.878374
#
#      CPU_rf  CPU_brif
# 0  4.124189  3.122504
#    dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  magic04  19020  10    1    13314  0.932523  0.929399  0.878023   0.866632
#
#      CPU_rf  CPU_brif
# 0  4.364725   3.60389
#    dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  magic04  19020  10    2    13314  0.931401  0.928077  0.874343    0.86891
#
#      CPU_rf  CPU_brif
# 0  4.158584  3.281669
#    dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  magic04  19020  10    3    13314  0.936715  0.933019  0.884508   0.874869
#
#      CPU_rf  CPU_brif
# 0  4.161138  3.270293
#    dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  magic04  19020  10    4    13314  0.937317  0.931556  0.880477   0.871889
#
#     CPU_rf  CPU_brif
# 0  4.33953  3.183755
#    dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  magic04  19020  10    5    13314  0.934112  0.931828  0.874518    0.86891
#
#      CPU_rf  CPU_brif
# 0  3.078947  3.233727
#    dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  magic04  19020  10    6    13314  0.933385  0.929721  0.874518   0.868384
#
#      CPU_rf  CPU_brif
# 0  3.446242  3.137445
#    dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  magic04  19020  10    7    13314  0.928983  0.924934  0.870487   0.859096
#
#      CPU_rf  CPU_brif
# 0  3.178882  3.349499
#    dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  magic04  19020  10    8    13314  0.931401  0.928423  0.876972   0.866982
#
#      CPU_rf  CPU_brif
# 0  3.999421     3.579
#    dataset      n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  magic04  19020  10    9    13314  0.936592  0.932635  0.881178    0.86926
#
#      CPU_rf  CPU_brif
# 0  3.899998  3.858511
#      dataset     n   p  run  train_n  AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  optdigits  5620  64    0     3934     1.0       1.0  0.985172   0.986358
#
#      CPU_rf  CPU_brif
# 0  0.543031  0.844039
#      dataset     n   p  run  train_n  AUC_rf  AUC_brif  ACCU_rf  ACCU_brif  \
# 0  optdigits  5620  64    1     3934     1.0       1.0  0.98102   0.985765
#
#      CPU_rf  CPU_brif
# 0  0.566253  0.770547
#      dataset     n   p  run  train_n  AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  optdigits  5620  64    2     3934     1.0       1.0  0.982206   0.985765
#
#      CPU_rf  CPU_brif
# 0  0.499374  0.795021
#      dataset     n   p  run  train_n   AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  optdigits  5620  64    3     3934  0.99997  0.999972  0.985172   0.986951
#
#      CPU_rf  CPU_brif
# 0  0.479421  0.779966
#      dataset     n   p  run  train_n  AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  optdigits  5620  64    4     3934     1.0       1.0  0.988138   0.988138
#
#      CPU_rf  CPU_brif
# 0  0.540541  0.719967
#      dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  optdigits  5620  64    5     3934  0.999935       1.0  0.978055   0.977461
#
#      CPU_rf  CPU_brif
# 0  0.549862  0.774812
#      dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  optdigits  5620  64    6     3934  0.999985  0.999989  0.978055   0.979834
#
#      CPU_rf  CPU_brif
# 0  0.490989  0.723515
#      dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  optdigits  5620  64    7     3934  0.999996       1.0  0.986951   0.985765
#
#      CPU_rf  CPU_brif
# 0  0.507662  0.730555
#      dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  optdigits  5620  64    8     3934  0.999983  0.999992  0.982206   0.983986
#
#      CPU_rf  CPU_brif
# 0  0.500458  0.708328
#      dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  optdigits  5620  64    9     3934  0.999948  0.999979  0.982206   0.985765
#
#      CPU_rf  CPU_brif
# 0  0.597569  0.789775
#     dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  spambase  4601  57    0     3221  0.991326  0.991384  0.957971   0.963043
#
#      CPU_rf  CPU_brif
# 0  0.456849  0.303103
#     dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  spambase  4601  57    1     3221  0.991477  0.990352  0.957971   0.955797
#
#      CPU_rf  CPU_brif
# 0  0.473152  0.272106
#     dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  spambase  4601  57    2     3221  0.987361  0.988431  0.951449   0.953623
#
#      CPU_rf  CPU_brif
# 0  0.431864  0.226002
#     dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  spambase  4601  57    3     3221  0.986867  0.989252  0.952899   0.955797
#
#      CPU_rf  CPU_brif
# 0  0.542325  0.225315
#     dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  spambase  4601  57    4     3221  0.989256  0.989334  0.951449   0.955072
#
#      CPU_rf  CPU_brif
# 0  0.457534  0.222171
#     dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  spambase  4601  57    5     3221  0.990271  0.990081  0.963768    0.95942
#
#      CPU_rf  CPU_brif
# 0  0.503639  0.248188
#     dataset     n   p  run  train_n   AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  spambase  4601  57    6     3221  0.99243  0.991944  0.960145   0.958696
#
#      CPU_rf  CPU_brif
# 0  0.514962  0.230233
#     dataset     n   p  run  train_n  AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  spambase  4601  57    7     3221  0.9818  0.984652  0.949275   0.951449
#
#      CPU_rf  CPU_brif
# 0  0.452231  0.224239
#     dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  spambase  4601  57    8     3221  0.987602  0.988593  0.958696   0.963043
#
#      CPU_rf  CPU_brif
# 0  0.496547  0.241724
#     dataset     n   p  run  train_n   AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  spambase  4601  57    9     3221  0.98493   0.98672  0.958696   0.958696
#
#      CPU_rf  CPU_brif
# 0  0.500063  0.240739
#    dataset     n   p  run  train_n    AUC_rf  AUC_brif  ACCU_rf  ACCU_brif  \
# 0  thyroid  3772  21    0     2640  0.999644  0.999288  0.99735   0.973498
#
#      CPU_rf  CPU_brif
# 0  0.258867  0.060085
#    dataset     n   p  run  train_n    AUC_rf  AUC_brif  ACCU_rf  ACCU_brif  \
# 0  thyroid  3772  21    1     2640  0.999826  0.999513  0.99735   0.979682
#
#     CPU_rf  CPU_brif
# 0  0.27161  0.056993
#    dataset     n   p  run  train_n    AUC_rf  AUC_brif  ACCU_rf  ACCU_brif  \
# 0  thyroid  3772  21    2     2640  0.999974  0.998681   0.9947   0.969081
#
#      CPU_rf  CPU_brif
# 0  0.307066  0.059999
#    dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  thyroid  3772  21    3     2640  0.999943  0.999915  0.998233   0.971731
#
#    CPU_rf  CPU_brif
# 0  0.2628  0.051104
#    dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  thyroid  3772  21    4     2640  0.999726  0.998824  0.996466   0.963781
#
#      CPU_rf  CPU_brif
# 0  0.274284  0.054317
#    dataset     n   p  run  train_n  AUC_rf  AUC_brif  ACCU_rf  ACCU_brif  \
# 0  thyroid  3772  21    5     2640     1.0  0.999698   0.9947   0.973498
#
#      CPU_rf  CPU_brif
# 0  0.274781  0.073003
#    dataset     n   p  run  train_n    AUC_rf  AUC_brif  ACCU_rf  ACCU_brif  \
# 0  thyroid  3772  21    6     2640  0.999812  0.999705  0.99735   0.964664
#
#      CPU_rf  CPU_brif
# 0  0.273702  0.067122
#    dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  thyroid  3772  21    7     2640  0.998399  0.998415  0.992933   0.969081
#
#      CPU_rf  CPU_brif
# 0  0.266004     0.051
#    dataset     n   p  run  train_n    AUC_rf  AUC_brif  ACCU_rf  ACCU_brif  \
# 0  thyroid  3772  21    8     2640  0.999896  0.999548   0.9947   0.968198
#
#    CPU_rf  CPU_brif
# 0   0.267  0.058473
#    dataset     n   p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  ACCU_brif  \
# 0  thyroid  3772  21    9     2640  0.999879  0.999728  0.998233   0.961131
#
#      CPU_rf  CPU_brif
# 0  0.274544  0.054005
#     dataset       n     p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  \
# 0      auto   392.0   7.0  0.0    274.0  0.970333  0.943962  0.923729
# 1      auto   392.0   7.0  1.0    274.0  0.957557  0.918367  0.881356
# 2      auto   392.0   7.0  2.0    274.0  0.966471  0.947059  0.915254
# 3      auto   392.0   7.0  3.0    274.0  0.932373  0.912258  0.855932
# 4      auto   392.0   7.0  4.0    274.0  0.953425  0.925723  0.872881
# ..      ...     ...   ...  ...      ...       ...       ...       ...
# 65  thyroid  3772.0  21.0  5.0   2640.0  1.000000  0.999698  0.994700
# 66  thyroid  3772.0  21.0  6.0   2640.0  0.999812  0.999705  0.997350
# 67  thyroid  3772.0  21.0  7.0   2640.0  0.998399  0.998415  0.992933
# 68  thyroid  3772.0  21.0  8.0   2640.0  0.999896  0.999548  0.994700
# 69  thyroid  3772.0  21.0  9.0   2640.0  0.999879  0.999728  0.998233
#
#     ACCU_brif    CPU_rf  CPU_brif
# 0    0.864407  0.169966  0.007000
# 1    0.855932  0.176373  0.008000
# 2    0.889831  0.174500  0.007996
# 3    0.855932  0.171213  0.007999
# 4    0.830508  0.166947  0.007999
# ..        ...       ...       ...
# 65   0.973498  0.274781  0.073003
# 66   0.964664  0.273702  0.067122
# 67   0.969081  0.266004  0.051000
# 68   0.968198  0.267000  0.058473
# 69   0.961131  0.274544  0.054005
#
# [70 rows x 11 columns]

# %%
log_df.groupby('dataset').mean()
# Out:
#                  n     p  run  train_n    AUC_rf  AUC_brif   ACCU_rf  \
# dataset
# HTRU2      17898.0   8.0  4.5  12529.0  0.969996  0.973728  0.979456
# auto         392.0   7.0  4.5    274.0  0.962275  0.939606  0.900000
# heloc      10459.0  23.0  4.5   7321.0  0.787306  0.788034  0.721765
# magic04    19020.0  10.0  4.5  13314.0  0.933943  0.930242  0.877655
# optdigits   5620.0  64.0  4.5   3934.0  0.999982  0.999993  0.982918
# spambase    4601.0  57.0  4.5   3221.0  0.988332  0.989074  0.956232
# thyroid     3772.0  21.0  4.5   2640.0  0.999710  0.999331  0.996201
#
#            ACCU_brif    CPU_rf  CPU_brif
# dataset
# HTRU2       0.976998  1.773270  0.529146
# auto        0.868644  0.171762  0.008099
# heloc       0.718356  0.736542  1.542041
# magic04     0.869331  3.875166  3.362029
# optdigits   0.984579  0.527516  0.763653
# spambase    0.957464  0.482917  0.243382
# thyroid     0.969435  0.273066  0.058610

# %% [markdown]
# Observation: brif and RandomForestClassifier performed neck and neck in all aspects.
